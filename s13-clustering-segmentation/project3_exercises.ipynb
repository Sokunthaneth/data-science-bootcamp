# %% [markdown]
# # Project 3: Predict Loan Default
# This notebook demonstrates how to segment borrowers using K-Means clustering, apply PCA for noise reduction, and analyze clusters for risk profiling in the context of loan default prediction.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ## 2. Load and Explore Data
# Replace the file path with your actual loan dataset.

# %%
# df = pd.read_csv('loan_data.csv')
# For demonstration, let's create a mock dataset
np.random.seed(42)
df = pd.DataFrame({
    'age': np.random.randint(21, 65, 200),
    'income': np.random.normal(50000, 15000, 200),
    'loan_amount': np.random.normal(15000, 5000, 200),
    'credit_score': np.random.normal(650, 50, 200),
    'default': np.random.choice([0, 1], 200, p=[0.8, 0.2])
})
df.head()
# Out:
#    age        income   loan_amount  credit_score  default
# 0   59  68555.241094  20721.857677    778.666248        1
# 1   49  28602.816729  19289.323294    618.799164        0
# 2   35  55070.339883  11865.710652    670.078028        0
# 3   63  79618.567954   8289.963480    732.347451        1
# 4   28  79475.521459  13370.134295    723.971696        0

# %% [markdown]
# ## 3. Preprocess Data
# Select features, handle missing values, and scale the data.

# %%
features = ['age', 'income', 'loan_amount', 'credit_score']
X = df[features]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
pd.DataFrame(X_scaled, columns=features).head()
# Out:
#         age    income  loan_amount  credit_score
# 0  1.191999  1.218021     1.083862      2.128964
# 1  0.436613 -1.476282     0.813791     -0.632164
# 2 -0.620927  0.308629    -0.585757      0.253493
# 3  1.494154  1.964107    -1.259880      1.328974
# 4 -1.149698  1.954460    -0.302133      1.184313

# %% [markdown]
# ## 4. Apply PCA to Reduce Noise
# Reduce dimensionality and visualize explained variance.

# %%
# Out:
# Explained variance ratio: [0.29947302 0.2596935 ]

# %% [markdown]
# ## 5. Segment Borrowers Using K-Means
# Use the elbow method to find the optimal number of clusters, then fit K-Means.

# %% [markdown]
# ## 6. Visualize Clusters
# Plot the clusters in the PCA-reduced space.

# %% [markdown]
# ## 7. Analyze Clusters for Risk Profiling
# Compare default rates and feature means across clusters.

# %%
# Out:
# Default rate by cluster:
# cluster
# 0    0.237288
# 1    0.180556
# 2    0.217391
# Name: default, dtype: float64
#                age        income   loan_amount  credit_score
# cluster
# 0        51.406780  60044.958538  12824.741950    628.206225
# 1        34.013889  41943.304585  12761.015856    635.473761
# 2        45.826087  51249.244202  19117.306184    699.448040

# %% [markdown]
# ---
# This notebook demonstrates how to segment borrowers using K-Means, reduce noise with PCA, and analyze clusters for risk profiling in a loan default prediction context. Replace the mock data with your actual dataset for real analysis.
